# %% [markdown]
# <a href="https://colab.research.google.com/github/ugrcnylmz/Assingment/blob/main/Customer_Segmentation_My_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using K-Means Clustering. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
# !pip install pyforest
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyforest
#   Downloading pyforest-1.1.0.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyforest
#   Building wheel for pyforest (setup.py) ... done
#   Created wheel for pyforest: filename=pyforest-1.1.0-py2.py3-none-any.whl size=14607 sha256=632636ba4959b4d65b0849f7bc33af738e8ce85c2870658a80fb114255ee35b5
#   Stored in directory: /root/.cache/pip/wheels/21/2d/19/8b5488f0caea6d892333413745640532d40d70e6b5351d7633
# Successfully built pyforest
# Installing collected packages: pyforest
# Successfully installed pyforest-1.1.0

# %%
import pyforest
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df.sample(10)
# Out:
#         InvoiceNo StockCode                        Description  Quantity  \
# 513393 579551.000 22624.000               IVORY KITCHEN SCALES     4.000
# 503949 578940.000 22898.000      CHILDRENS APRON APPLES DESIGN     5.000
# 330173 565916.000 85053.000         FRENCH ENAMEL CANDLEHOLDER     6.000
# 168310 551016.000 22295.000          HEART FILIGREE DOVE LARGE    12.000
# 461608 575947.000 21559.000  STRAWBERRY LUNCH BOX WITH CUTLERY     1.000
# 116801 546306.000 22309.000               TEA COSY RED  STRIPE     1.000
# 357497 568095.000 90166.000          PINK & WHITE ROSEBUD RING     3.000
# 28064  538625.000 22639.000      SET OF 4 NAPKIN CHARMS HEARTS    32.000
# 270321    C560560 22423.000           REGENCY CAKESTAND 3 TIER    -1.000
# 119407 546542.000 20751.000   FUNKY WASHING UP GLOVES ASSORTED     1.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 513393 2011-11-30 10:49:00      8.500   15782.000  United Kingdom
# 503949 2011-11-27 13:18:00      4.960         NaN  United Kingdom
# 330173 2011-09-07 16:00:00      2.100   14156.000            EIRE
# 168310 2011-04-26 11:09:00      1.650   17975.000  United Kingdom
# 461608 2011-11-13 11:50:00      4.960         NaN  United Kingdom
# 116801 2011-03-10 16:16:00      4.960         NaN  United Kingdom
# 357497 2011-09-23 14:49:00      4.250   14911.000            EIRE
# 28064  2010-12-13 12:50:00      2.100   14544.000  United Kingdom
# 270321 2011-07-19 13:26:00     12.750   17738.000  United Kingdom
# 119407 2011-03-14 15:13:00      2.100   13263.000  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 33.1+ MB

# %%
df.shape
# Out:
# (541909, 8)

# %%
df[df.duplicated()]
# Out:
#         InvoiceNo StockCode                        Description  Quantity  \
# 517    536409.000 21866.000        UNION JACK FLAG LUGGAGE TAG     1.000
# 527    536409.000 22866.000      HAND WARMER SCOTTY DOG DESIGN     1.000
# 537    536409.000 22900.000    SET 2 TEA TOWELS I LOVE LONDON      1.000
# 539    536409.000 22111.000       SCOTTIE DOG HOT WATER BOTTLE     1.000
# 555    536412.000 22327.000  ROUND SNACK BOXES SET OF 4 SKULLS     1.000
# ...           ...       ...                                ...       ...
# 541675 581538.000 22068.000        BLACK PIRATE TREASURE CHEST     1.000
# 541689 581538.000 23318.000     BOX OF 6 MINI VINTAGE CRACKERS     1.000
# 541692 581538.000 22992.000             REVOLVER WOODEN RULER      1.000
# 541699 581538.000 22694.000                       WICKER STAR      1.000
# 541701 581538.000 23343.000       JUMBO BAG VINTAGE CHRISTMAS      1.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 517    2010-12-01 11:45:00      1.250   17908.000  United Kingdom
# 527    2010-12-01 11:45:00      2.100   17908.000  United Kingdom
# 537    2010-12-01 11:45:00      2.950   17908.000  United Kingdom
# 539    2010-12-01 11:45:00      4.950   17908.000  United Kingdom
# 555    2010-12-01 11:49:00      2.950   17920.000  United Kingdom
# ...                    ...        ...         ...             ...
# 541675 2011-12-09 11:34:00      0.390   14446.000  United Kingdom
# 541689 2011-12-09 11:34:00      2.490   14446.000  United Kingdom
# 541692 2011-12-09 11:34:00      1.950   14446.000  United Kingdom
# 541699 2011-12-09 11:34:00      2.100   14446.000  United Kingdom
# 541701 2011-12-09 11:34:00      2.080   14446.000  United Kingdom
#
# [5268 rows x 8 columns]

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df[(df.InvoiceNo == 536409)& (df.Description == 'UNION JACK FLAG LUGGAGE TAG')]
# Out:
#      InvoiceNo StockCode                  Description  Quantity  \
# 494 536409.000 21866.000  UNION JACK FLAG LUGGAGE TAG     1.000
# 517 536409.000 21866.000  UNION JACK FLAG LUGGAGE TAG     1.000
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 494 2010-12-01 11:45:00      1.250   17908.000  United Kingdom
# 517 2010-12-01 11:45:00      1.250   17908.000  United Kingdom

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (536641, 8)

# %%
for column in df.select_dtypes('object').columns:
    print(f'Column {column} has {df[column].nunique()} unique values.')
# Out:
# Column InvoiceNo has 25900 unique values.
# Column StockCode has 4070 unique values.
# Column Description has 4223 unique values.
# Column Country has 38 unique values.

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df.describe().T
# Out:
#                 count      mean      std        min       25%       50%  \
# Quantity   536641.000     9.620  219.130 -80995.000     1.000     3.000
# UnitPrice  536641.000     4.633   97.233 -11062.060     1.250     2.080
# CustomerID 401604.000 15281.161 1714.006  12346.000 13939.000 15145.000
#
#                  75%       max
# Quantity      10.000 80995.000
# UnitPrice      4.130 38970.000
# CustomerID 16784.000 18287.000

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %%
df[df['InvoiceNo'] == 563557 ][['Quantity',"UnitPrice",'Description']].sample(10)
# Out:
#         Quantity  UnitPrice                      Description
# 303951    12.000      1.450  SET OF 36 TEATIME PAPER DOILIES
# 303943    12.000      1.250    SET OF 3 HEART COOKIE CUTTERS
# 303875     3.000      5.450      BLUE HAPPY BIRTHDAY BUNTING
# 303986    12.000      1.450   SINGLE ANTIQUE ROSE HOOK IVORY
# 303894    12.000      1.250              HAPPY STENCIL CRAFT
# 304010     6.000      2.950  NATURAL SLATE HEART CHALKBOARD
# 303976    24.000      1.650  DRAWER KNOB CRACKLE GLAZE GREEN
# 303970    24.000      0.550  PACK OF 72 RETROSPOT CAKE CASES
# 303954    12.000      1.450   SET OF 72 SKULL PAPER  DOILIES
# 303888    12.000      1.650          BAG 500g SWIRLY MARBLES

# %%
df[['Quantity',"UnitPrice"]].corr().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_8b861_row0_col0, #T_8b861_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8b861_row0_col1, #T_8b861_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_8b861_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Quantity</th>
#       <th class="col_heading level0 col1" >UnitPrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b861_level0_row0" class="row_heading level0 row0" >Quantity</th>
#       <td id="T_8b861_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8b861_row0_col1" class="data row0 col1" >-0.001241</td>
#     </tr>
#     <tr>
#       <th id="T_8b861_level0_row1" class="row_heading level0 row1" >UnitPrice</th>
#       <td id="T_8b861_row1_col0" class="data row1 col0" >-0.001241</td>
#       <td id="T_8b861_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df
# 354213 567866.000         M      Manual     5.000 2011-09-22 14:13:00
# 520133    C580263         M      Manual    -4.000 2011-12-02 12:43:00
# 200745 554155.000         M      Manual     1.000 2011-05-23 11:26:00
# 28007  538597.000         M      Manual     1.000 2010-12-13 12:26:00
#
#         UnitPrice  CustomerID         Country
# 524894      0.850   12748.000  United Kingdom
# 177984    189.440         NaN  United Kingdom
# 400626    283.020   12783.000        Portugal
# 410388      1.250   17571.000  United Kingdom
# 392671      0.190   12908.000  United Kingdom
# 29551      20.000   17194.000  United Kingdom
# 269177    705.450   17603.000  United Kingdom
# 523375      1.250   14456.000  United Kingdom
# 504904      1.000   13991.000  United Kingdom
# 118006      0.420   17315.000  United Kingdom
# 489132      1.250   15525.000  United Kingdom
# 487614      2.550   16712.000  United Kingdom
# 41448    1298.400         NaN  United Kingdom
# 326601      4.000   18283.000  United Kingdom
# 348583      0.190   15888.000  United Kingdom
# 270558    112.350         NaN  United Kingdom
# 354213      0.800   16669.000  United Kingdom
# 520133      9.950   12536.000          France
# 200745   1241.980   12757.000        Portugal
# 28007       1.250   15555.000  United Kingdom

# %%
df[df['StockCode'] == 22423].sample(20)
# Out:
#         InvoiceNo StockCode               Description  Quantity  \
# 187990 553013.000 22423.000  REGENCY CAKESTAND 3 TIER    12.000
# 521092 580311.000 22423.000  REGENCY CAKESTAND 3 TIER     2.000
# 378035 569579.000 22423.000  REGENCY CAKESTAND 3 TIER     2.000
# 203769 554555.000 22423.000  REGENCY CAKESTAND 3 TIER     4.000
# 363081 568537.000 22423.000  REGENCY CAKESTAND 3 TIER    40.000
# 86681  543591.000 22423.000  REGENCY CAKESTAND 3 TIER    16.000
# 93687  544305.000 22423.000  REGENCY CAKESTAND 3 TIER     3.000
# 314384 564634.000 22423.000  REGENCY CAKESTAND 3 TIER     4.000
# 18133     C537797 22423.000  REGENCY CAKESTAND 3 TIER    -2.000
# 386153 570227.000 22423.000  REGENCY CAKESTAND 3 TIER    20.000
# 198286    C554029 22423.000  REGENCY CAKESTAND 3 TIER    -1.000
# 220644 556205.000 22423.000  REGENCY CAKESTAND 3 TIER     1.000
# 338511 566559.000 22423.000  REGENCY CAKESTAND 3 TIER     2.000
# 59601  541316.000 22423.000  REGENCY CAKESTAND 3 TIER     1.000
# 31586  538996.000 22423.000  REGENCY CAKESTAND 3 TIER    16.000
# 55390  540993.000 22423.000  REGENCY CAKESTAND 3 TIER     2.000
# 17772  537775.000 22423.000  REGENCY CAKESTAND 3 TIER     4.000
# 107320 545428.000 22423.000  REGENCY CAKESTAND 3 TIER     4.000
# 475539 576899.000 22423.000  REGENCY CAKESTAND 3 TIER     7.000
# 314962 564670.000 22423.000  REGENCY CAKESTAND 3 TIER    16.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 187990 2011-05-12 18:19:00     12.750         NaN  United Kingdom
# 521092 2011-12-02 14:48:00     12.750   18245.000  United Kingdom
# 378035 2011-10-05 11:06:00     12.750   17666.000  United Kingdom
# 203769 2011-05-25 10:08:00     12.750   12437.000          France
# 363081 2011-09-27 14:04:00     10.950   15061.000  United Kingdom
# 86681  2011-02-10 11:46:00     10.950   13854.000  United Kingdom
# 93687  2011-02-17 13:54:00     12.750   15044.000  United Kingdom
# 314384 2011-08-26 12:36:00     12.750   14210.000  United Kingdom
# 18133  2010-12-08 13:07:00     10.950   13113.000  United Kingdom
# 386153 2011-10-09 13:21:00     10.950   13260.000  United Kingdom
# 198286 2011-05-20 13:54:00     12.750   12681.000          France
# 220644 2011-06-09 13:37:00     12.750   15827.000  United Kingdom
# 338511 2011-09-13 11:52:00     12.750   18044.000  United Kingdom
# 59601  2011-01-17 14:27:00     12.750   13209.000  United Kingdom
# 31586  2010-12-15 12:06:00     10.950   15465.000  United Kingdom
# 55390  2011-01-13 09:23:00     12.750   13284.000  United Kingdom
# 17772  2010-12-08 12:41:00     12.750   17722.000  United Kingdom
# 107320 2011-03-02 14:43:00     12.750   14239.000  United Kingdom
# 475539 2011-11-17 08:49:00     12.750   14911.000            EIRE
# 314962 2011-08-26 15:44:00     10.950   12683.000          France

# %% [markdown]
# #### Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %% [markdown]
# ### iii. Handling Missing Values

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %%
df.CustomerID.isnull().count()
# Out:
# 536641

# %%
df.dropna(subset=['CustomerID'],inplace = True)

# %%
df[df.CustomerID.isnull()==True].count()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.shape
# Out:
# (401604, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  float64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 27.6+ MB

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df[df['CustomerID']==13256]
# Out:
#         InvoiceNo StockCode                     Description  Quantity  \
# 502122 578841.000 84826.000  ASSTD DESIGN 3D PAPER STICKERS 12540.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 502122 2011-11-25 15:57:00      0.000   13256.000  United Kingdom

# %%
df.Description.isnull().sum()
# Out:
# 0

# %%
df[(df['Quantity']<0) | (df['UnitPrice']<0)][df.InvoiceNo.str.contains('C') == False]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 541904 581587.000 22613.000          PACK OF 20 SPACEBOY NAPKINS    12.000
# 541905 581587.000 22899.000         CHILDREN'S APRON DOLLY GIRL      6.000
# 541906 581587.000 23254.000        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 541907 581587.000 23255.000      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 541908 581587.000 22138.000        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00      2.550   17850.000  United Kingdom
# 1      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 2      2010-12-01 08:26:00      2.750   17850.000  United Kingdom
# 3      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 4      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00      0.850   12680.000          France
# 541905 2011-12-09 12:50:00      2.100   12680.000          France
# 541906 2011-12-09 12:50:00      4.150   12680.000          France
# 541907 2011-12-09 12:50:00      4.150   12680.000          France
# 541908 2011-12-09 12:50:00      4.950   12680.000          France
#
# [401604 rows x 8 columns]

# %%
df1=df[~df["InvoiceNo"].str.contains("C", na=False)]

# %%
df1= df[(df["Quantity"]>0)]

# %%
df1.shape
# Out:
# (392732, 8)

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df1.groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 12748.000    210
# 14911.000    201
# 17841.000    124
# 13089.000     97
# 14606.000     93
#             ...
# 14355.000      1
# 13403.000      1
# 15488.000      1
# 14353.000      1
# 12346.000      1
# Name: InvoiceNo, Length: 4339, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df1.groupby('CustomerID')['StockCode'].count().mean()
# Out:
# 90.51209956211109

# %%
df1.groupby('InvoiceNo')['StockCode'].count().mean()
# Out:
# 21.187526974536038

# %%
df1.groupby(['CustomerID', 'InvoiceNo'])['StockCode'].count()
# Out:
# CustomerID  InvoiceNo
# 12346.000   541431.000     1
# 12347.000   537626.000    31
#             542237.000    29
#             549222.000    24
#             556201.000    18
#                           ..
# 18283.000   579673.000    50
#             580872.000    50
# 18287.000   554065.000    29
#             570715.000    38
#             573167.000     3
# Name: StockCode, Length: 18536, dtype: int64

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df1.groupby('CustomerID')['StockCode'].nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 14911.000    1787
# 12748.000    1768
# 17841.000    1323
# 14096.000    1119
# 14298.000     884
#              ...
# 13366.000       1
# 13391.000       1
# 13452.000       1
# 16078.000       1
# 12346.000       1
# Name: StockCode, Length: 4339, dtype: int64

# %% [markdown]
# ### vi. Explore Customers by Country

# %%
df["Country"].value_counts().plot(kind="pie", autopct='%1.1f%%',figsize=(12,10));

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df1['Total_Price'] =(df1.UnitPrice) * (df1.Quantity)

# %%
df1.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0 536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1 536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2 536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3 536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4 536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total_Price
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom       15.300
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom       20.340
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom       22.000
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom       20.340
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom       20.340

# %%
df1.groupby('Country')['Total_Price'].sum().sort_values(ascending = False)
# Out:
# Country
# United Kingdom         7285024.644
# Netherlands             285446.340
# EIRE                    265262.460
# Germany                 228678.400
# France                  208934.310
# Australia               138453.810
# Spain                    61558.560
# Switzerland              56443.950
# Belgium                  41196.340
# Sweden                   38367.830
# Japan                    37416.370
# Norway                   36165.440
# Portugal                 33375.840
# Finland                  22546.080
# Singapore                21279.290
# Channel Islands          20440.540
# Denmark                  18955.340
# Italy                    17483.240
# Cyprus                   13502.850
# Austria                  10198.680
# Poland                    7334.650
# Israel                    7215.840
# Greece                    4760.520
# Iceland                   4310.000
# Canada                    3666.380
# USA                       3580.390
# Malta                     2725.590
# Unspecified               2660.770
# United Arab Emirates      1902.280
# Lebanon                   1693.880
# Lithuania                 1661.060
# European Community        1300.250
# Brazil                    1143.600
# RSA                       1002.310
# Czech Republic             826.740
# Bahrain                    548.400
# Saudi Arabia               145.920
# Name: Total_Price, dtype: float64

# %% [markdown]
# 2. Visualize number of customer per country

# %%
xx =df1.groupby(['Country'])['CustomerID'].nunique().sort_values(ascending=False)
plt.figure(figsize=(12,10))
sns.barplot(xx.values,xx.index)

# %% [markdown]
# 3. Visualize total cost per country

# %%
xx =df1.groupby(['Country'])['Total_Price'].sum().sort_values(ascending=False)
plt.figure(figsize=(12,10))
sns.barplot(xx.values,xx.index)

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk=df1[df1.Country=='United Kingdom']

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df_uk.groupby(['StockCode','Description'])[['Quantity']].sum().sort_values(by='Quantity',ascending=False).head()
# Out:
#                                               Quantity
# StockCode Description
# 23843.0   PAPER CRAFT , LITTLE BIRDIE        80995.000
# 23166.0   MEDIUM CERAMIC TOP STORAGE JAR     76919.000
# 84077.0   WORLD WAR 2 GLIDERS ASSTD DESIGNS  49086.000
# 85099B    JUMBO BAG RED RETROSPOT            41878.000
# 85123A    WHITE HANGING HEART T-LIGHT HOLDER 34630.000

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt
from datetime import timedelta

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349227 entries, 0 to 541893
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349227 non-null  object
#  1   StockCode    349227 non-null  object
#  2   Description  349227 non-null  object
#  3   Quantity     349227 non-null  float64
#  4   InvoiceDate  349227 non-null  datetime64[ns]
#  5   UnitPrice    349227 non-null  float64
#  6   CustomerID   349227 non-null  float64
#  7   Country      349227 non-null  object
#  8   Total_Price  349227 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 26.6+ MB

# %%
df_uk.shape
# Out:
# (349227, 9)

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349227 entries, 0 to 541893
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349227 non-null  object
#  1   StockCode    349227 non-null  object
#  2   Description  349227 non-null  object
#  3   Quantity     349227 non-null  float64
#  4   InvoiceDate  349227 non-null  datetime64[ns]
#  5   UnitPrice    349227 non-null  float64
#  6   CustomerID   349227 non-null  float64
#  7   Country      349227 non-null  object
#  8   Total_Price  349227 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 26.6+ MB

# %%
ref_date = df_uk['InvoiceDate'].max()+timedelta(days=3)
ref_date
# Out:
# Timestamp('2011-12-12 12:49:00')

# %%
df_rec = pd.DataFrame(df_uk.groupby('CustomerID')['InvoiceDate'].max().dt.date)
df_rec
# Out:
#            InvoiceDate
# CustomerID
# 12346.000   2011-01-18
# 12747.000   2011-12-07
# 12748.000   2011-12-09
# 12749.000   2011-12-06
# 12820.000   2011-12-06
# ...                ...
# 18280.000   2011-03-07
# 18281.000   2011-06-12
# 18282.000   2011-12-02
# 18283.000   2011-12-06
# 18287.000   2011-10-28
#
# [3921 rows x 1 columns]

# %%
df_rec['ref_date'] = ref_date
df_rec["ref_date"] = df_rec["ref_date"].dt.date
df_rec
# Out:
#            InvoiceDate    ref_date
# CustomerID
# 12346.000   2011-01-18  2011-12-12
# 12747.000   2011-12-07  2011-12-12
# 12748.000   2011-12-09  2011-12-12
# 12749.000   2011-12-06  2011-12-12
# 12820.000   2011-12-06  2011-12-12
# ...                ...         ...
# 18280.000   2011-03-07  2011-12-12
# 18281.000   2011-06-12  2011-12-12
# 18282.000   2011-12-02  2011-12-12
# 18283.000   2011-12-06  2011-12-12
# 18287.000   2011-10-28  2011-12-12
#
# [3921 rows x 2 columns]

# %%
df_rec["Last_Purchased"] = df_rec.ref_date - df_rec["InvoiceDate"]
df_rec
# Out:
#            InvoiceDate    ref_date Last_Purchased
# CustomerID
# 12346.000   2011-01-18  2011-12-12       328 days
# 12747.000   2011-12-07  2011-12-12         5 days
# 12748.000   2011-12-09  2011-12-12         3 days
# 12749.000   2011-12-06  2011-12-12         6 days
# 12820.000   2011-12-06  2011-12-12         6 days
# ...                ...         ...            ...
# 18280.000   2011-03-07  2011-12-12       280 days
# 18281.000   2011-06-12  2011-12-12       183 days
# 18282.000   2011-12-02  2011-12-12        10 days
# 18283.000   2011-12-06  2011-12-12         6 days
# 18287.000   2011-10-28  2011-12-12        45 days
#
# [3921 rows x 3 columns]

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_rec['Date']= df_rec.InvoiceDate
df_rec
# Out:
#            InvoiceDate    ref_date Last_Purchased        Date
# CustomerID
# 12346.000   2011-01-18  2011-12-12       328 days  2011-01-18
# 12747.000   2011-12-07  2011-12-12         5 days  2011-12-07
# 12748.000   2011-12-09  2011-12-12         3 days  2011-12-09
# 12749.000   2011-12-06  2011-12-12         6 days  2011-12-06
# 12820.000   2011-12-06  2011-12-12         6 days  2011-12-06
# ...                ...         ...            ...         ...
# 18280.000   2011-03-07  2011-12-12       280 days  2011-03-07
# 18281.000   2011-06-12  2011-12-12       183 days  2011-06-12
# 18282.000   2011-12-02  2011-12-12        10 days  2011-12-02
# 18283.000   2011-12-06  2011-12-12         6 days  2011-12-06
# 18287.000   2011-10-28  2011-12-12        45 days  2011-10-28
#
# [3921 rows x 4 columns]

# %%
df_uk["Date"] = df_uk.groupby('CustomerID')['InvoiceDate'].transform(max).dt.date

# %%
df_uk.isnull().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description    False
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID     False
# Country        False
# Total_Price    False
# Date           False
# dtype: bool

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
df_uk.groupby('CustomerID')['InvoiceDate'].max()
# Out:
# CustomerID
# 12346.000   2011-01-18 10:01:00
# 12747.000   2011-12-07 14:34:00
# 12748.000   2011-12-09 12:20:00
# 12749.000   2011-12-06 09:56:00
# 12820.000   2011-12-06 15:12:00
#                     ...
# 18280.000   2011-03-07 09:52:00
# 18281.000   2011-06-12 10:53:00
# 18282.000   2011-12-02 11:43:00
# 18283.000   2011-12-06 12:02:00
# 18287.000   2011-10-28 09:29:00
# Name: InvoiceDate, Length: 3921, dtype: datetime64[ns]

# %%
df_uk.CustomerID.nunique()
# Out:
# 3921

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
df_rec["Last_Purchased"].sort_values(ascending=False)#.astype("int64")
# Out:
# CustomerID
# 17643.000   376 days
# 15165.000   376 days
# 13747.000   376 days
# 17908.000   376 days
# 17968.000   376 days
#               ...
# 17581.000     3 days
# 17364.000     3 days
# 14051.000     3 days
# 15311.000     3 days
# 13113.000     3 days
# Name: Last_Purchased, Length: 3921, dtype: timedelta64[ns]

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df_rec = df_rec.drop(axis = 1,columns = ["Date","ref_date","InvoiceDate"])

# %%
df_rec
# Out:
#            Last_Purchased
# CustomerID
# 12346.000        328 days
# 12747.000          5 days
# 12748.000          3 days
# 12749.000          6 days
# 12820.000          6 days
# ...                   ...
# 18280.000        280 days
# 18281.000        183 days
# 18282.000         10 days
# 18283.000          6 days
# 18287.000         45 days
#
# [3921 rows x 1 columns]

# %%
df_rec["Recency"] = pd.to_numeric(df_rec['Last_Purchased'].dt.days.astype('int16'))

# %%
df_rec.drop(columns= "Last_Purchased", inplace = True)

# %%
df_rec = pd.DataFrame(df_rec)
df_rec
# Out:
#             Recency
# CustomerID
# 12346.000       328
# 12747.000         5
# 12748.000         3
# 12749.000         6
# 12820.000         6
# ...             ...
# 18280.000       280
# 18281.000       183
# 18282.000        10
# 18283.000         6
# 18287.000        45
#
# [3921 rows x 1 columns]

# %% [markdown]
# 6. Plot RFM distributions

# %%
plt.figure(figsize=(10,8))
sns.distplot(df_rec.Recency, kde = False)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df_rec.Recency)

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uk2 = df_uk.copy()
df_uk2
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 541889 581585.000 22466.000       FAIRY TALE COTTAGE NIGHT LIGHT    12.000
# 541890 581586.000 22061.000  LARGE CAKE STAND  HANGING STRAWBERY     8.000
# 541891 581586.000 23275.000     SET OF 3 HANGING OWLS OLLIE BEAK    24.000
# 541892 581586.000 21217.000        RED RETROSPOT ROUND CAKE TINS    24.000
# 541893 581586.000 20685.000                DOORMAT RED RETROSPOT    10.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 0      2010-12-01 08:26:00      2.550   17850.000  United Kingdom
# 1      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 2      2010-12-01 08:26:00      2.750   17850.000  United Kingdom
# 3      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 4      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# ...                    ...        ...         ...             ...
# 541889 2011-12-09 12:31:00      1.950   15804.000  United Kingdom
# 541890 2011-12-09 12:49:00      2.950   13113.000  United Kingdom
# 541891 2011-12-09 12:49:00      1.250   13113.000  United Kingdom
# 541892 2011-12-09 12:49:00      8.950   13113.000  United Kingdom
# 541893 2011-12-09 12:49:00      7.080   13113.000  United Kingdom
#
#         Total_Price        Date
# 0            15.300  2010-12-02
# 1            20.340  2010-12-02
# 2            22.000  2010-12-02
# 3            20.340  2010-12-02
# 4            20.340  2010-12-02
# ...             ...         ...
# 541889       23.400  2011-12-09
# 541890       23.600  2011-12-09
# 541891       30.000  2011-12-09
# 541892      214.800  2011-12-09
# 541893       70.800  2011-12-09
#
# [349227 rows x 10 columns]

# %%
df_uk2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
df_freq = pd.DataFrame(df_uk.groupby('CustomerID')['InvoiceNo'].nunique())

# %%
df_freq.rename(columns = {"InvoiceNo" : "Frequency"}, inplace =True)

# %%
df_freq.head()
# Out:
#             Frequency
# CustomerID
# 12346.000           1
# 12747.000          11
# 12748.000         210
# 12749.000           5
# 12820.000           4

# %% [markdown]
# 3. Plot RFM distributions

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df_freq.Frequency);

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
df_money = pd.DataFrame(df_uk.groupby("CustomerID")["Total_Price"].sum())

# %%
df_money
# Out:
#             Total_Price
# CustomerID
# 12346.000     77183.600
# 12747.000      4196.010
# 12748.000     33053.190
# 12749.000      4090.880
# 12820.000       942.340
# ...                 ...
# 18280.000       180.600
# 18281.000        80.820
# 18282.000       178.050
# 18283.000      2045.530
# 18287.000      1837.280
#
# [3921 rows x 1 columns]

# %%
df_money.rename(columns = {'Total_Price':'Monetary'}, inplace = True)

# %%
df_money.head()
# Out:
#             Monetary
# CustomerID
# 12346.000  77183.600
# 12747.000   4196.010
# 12748.000  33053.190
# 12749.000   4090.880
# 12820.000    942.340

# %% [markdown]
# 2. Plot RFM distributions

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df_money.Monetary);

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
df_RFM = pd.merge(df_rec, df_freq, on = "CustomerID")

# %%
df_RFM = pd.merge(df_RFM, df_money, on = "CustomerID")

# %%
df_RFM.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.000       328          1 77183.600
# 12747.000         5         11  4196.010
# 12748.000         3        210 33053.190
# 12749.000         6          5  4090.880
# 12820.000         6          4   942.340

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %%
df_RFM.describe().T
# Out:
#              count     mean      std   min     25%     50%      75%        max
# Recency   3921.000   94.722   99.529 3.000  20.000  53.000  145.000    376.000
# Frequency 3921.000    4.246    7.206 1.000   1.000   2.000    5.000    210.000
# Monetary  3921.000 1857.951 7477.736 0.000 298.110 644.300 1570.810 259657.300

# %%
def moneteray_score(rfm):
    if rfm.Monetary <= 298.110:
        moneteray_score = 1
    elif rfm.Monetary <= 644.300:
        moneteray_score = 2
    elif rfm.Monetary <= 1570.810:
        moneteray_score = 3
    else:
        moneteray_score = 4
    return moneteray_score
df_RFM['M'] = df_RFM.apply(moneteray_score, axis=1)
df_RFM.head()
#Harcadigi para miktarina gore scorelar
# Out:
#             Recency  Frequency  Monetary  M
# CustomerID
# 12346.000       328          1 77183.600  4
# 12747.000         5         11  4196.010  4
# 12748.000         3        210 33053.190  4
# 12749.000         6          5  4090.880  4
# 12820.000         6          4   942.340  3

# %%
def frequncy_scor(rfm):
    if rfm.Frequency <= 1:
        frequncy_scor = 1
    elif rfm.Frequency <= 2:
        frequncy_scor = 2
    elif rfm.Frequency <= 5:
        frequncy_scor =3
    else:
        frequncy_scor = 4
    return frequncy_scor
df_RFM['F'] = df_RFM.apply(frequncy_scor, axis=1)
df_RFM.head()
#Alisveris yaptigi sikliga gore scorelar.
# Out:
#             Recency  Frequency  Monetary  M  F
# CustomerID
# 12346.000       328          1 77183.600  4  1
# 12747.000         5         11  4196.010  4  4
# 12748.000         3        210 33053.190  4  4
# 12749.000         6          5  4090.880  4  3
# 12820.000         6          4   942.340  3  3

# %%
def recency_scoring(rfm):
    if rfm.Recency <= 17.0:
        recency_score = 4
    elif rfm.Recency <= 50.0:
        recency_score = 3
    elif rfm.Recency <= 142.0:
        recency_score = 2
    else:
        recency_score = 1
    return recency_score
df_RFM['R'] = df_RFM.apply(recency_scoring, axis=1)
df_RFM.head()
#En son yaptigi alisveris tarihini hesaplar
# Out:
#             Recency  Frequency  Monetary  M  F  R
# CustomerID
# 12346.000       328          1 77183.600  4  1  1
# 12747.000         5         11  4196.010  4  4  4
# 12748.000         3        210 33053.190  4  4  4
# 12749.000         6          5  4090.880  4  3  4
# 12820.000         6          4   942.340  3  3  4

# %%
df_RFM.head()
# Out:
#             Recency  Frequency  Monetary  M  F  R
# CustomerID
# 12346.000       328          1 77183.600  4  1  1
# 12747.000         5         11  4196.010  4  4  4
# 12748.000         3        210 33053.190  4  4  4
# 12749.000         6          5  4090.880  4  3  4
# 12820.000         6          4   942.340  3  3  4

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
df_RFM.head()
# Out:
#             Recency  Frequency  Monetary  M  F  R
# CustomerID
# 12346.000       328          1 77183.600  4  1  1
# 12747.000         5         11  4196.010  4  4  4
# 12748.000         3        210 33053.190  4  4  4
# 12749.000         6          5  4090.880  4  3  4
# 12820.000         6          4   942.340  3  3  4

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
def weighted_rfm(y): # Recency için 2,  Frequency için 3 , Monetary için 5. seklinde agirlik verdik.
    return y.R*2 + y.F*3 + y.M*5
df_RFM["WeightedRFM_score"] = df_RFM.apply(weighted_rfm,axis=1)

# %%
def rfm_score(x):
    return str(x.R) + str(x.F) + str(x.M)
df_RFM["RFM_LABEL"] = df_RFM.apply(rfm_score,axis=1)

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %%
df_RFM.head()
# Out:
#             Recency  Frequency  Monetary  M  F  R  WeightedRFM_score  \
# CustomerID
# 12346.000       328          1 77183.600  4  1  1             25.000
# 12747.000         5         11  4196.010  4  4  4             40.000
# 12748.000         3        210 33053.190  4  4  4             40.000
# 12749.000         6          5  4090.880  4  3  4             37.000
# 12820.000         6          4   942.340  3  3  4             32.000
#
#             RFM_LABEL
# CustomerID
# 12346.000   1.01.04.0
# 12747.000   4.04.04.0
# 12748.000   4.04.04.0
# 12749.000   4.03.04.0
# 12820.000   4.03.03.0

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
def cathegorizer(x):
    if x.WeightedRFM_score >35:
        x = 'Loyal Customers'
        
    elif x.WeightedRFM_score >30:
        x = 'Potential Loyalist'
        
    elif x.WeightedRFM_score >25:
        x = 'Good Customers'
    
    elif  x.WeightedRFM_score >20:
        x = 'Customers Needing Attention'
    
    elif  x.WeightedRFM_score >15:
        x = 'Try to Get Them Back'
    
    elif  x.WeightedRFM_score >=10:
        x = 'Losted Customer'
 
    return x 
df_RFM["RFM_Level"] = df_RFM.apply(cathegorizer,axis=1)
df_RFM
# Out:
#             Recency  Frequency  Monetary  M  F  R  WeightedRFM_score  \
# CustomerID
# 12346.000       328          1 77183.600  4  1  1             25.000
# 12747.000         5         11  4196.010  4  4  4             40.000
# 12748.000         3        210 33053.190  4  4  4             40.000
# 12749.000         6          5  4090.880  4  3  4             37.000
# 12820.000         6          4   942.340  3  3  4             32.000
# ...             ...        ...       ... .. .. ..                ...
# 18280.000       280          1   180.600  1  1  1             10.000
# 18281.000       183          1    80.820  1  1  1             10.000
# 18282.000        10          2   178.050  1  2  4             19.000
# 18283.000         6         16  2045.530  4  4  4             40.000
# 18287.000        45          3  1837.280  4  3  3             35.000
#
#             RFM_LABEL                    RFM_Level
# CustomerID
# 12346.000   1.01.04.0  Customers Needing Attention
# 12747.000   4.04.04.0              Loyal Customers
# 12748.000   4.04.04.0              Loyal Customers
# 12749.000   4.03.04.0              Loyal Customers
# 12820.000   4.03.03.0           Potential Loyalist
# ...               ...                          ...
# 18280.000   1.01.01.0              Losted Customer
# 18281.000   1.01.01.0              Losted Customer
# 18282.000   4.02.01.0         Try to Get Them Back
# 18283.000   4.04.04.0              Loyal Customers
# 18287.000   3.03.04.0           Potential Loyalist
#
# [3921 rows x 9 columns]

# %%
plt.figure(figsize=(12,8))
ax = sns.displot(df_RFM.RFM_Level,kde=False)
ax.set_xticklabels(rotation = 30)

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
df_RFM.RFM_Level.value_counts()
# Out:
# Losted Customer                1043
# Loyal Customers                 721
# Good Customers                  581
# Try to Get Them Back            579
# Customers Needing Attention     539
# Potential Loyalist              458
# Name: RFM_Level, dtype: int64

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
RFM_segments= pd.DataFrame(df_RFM.RFM_Level.value_counts(dropna=False).sort_values(ascending=False))
RFM_segments.reset_index(inplace=True)
RFM_segments.rename(columns={'index':'RFM_segments', 'RFM_Level':'Customers'}, inplace=True)
RFM_segments
# Out:
#                   RFM_segments  Customers
# 0              Losted Customer       1043
# 1              Loyal Customers        721
# 2               Good Customers        581
# 3         Try to Get Them Back        579
# 4  Customers Needing Attention        539
# 5           Potential Loyalist        458

# %%
plt.figure(figsize=(19, 8))
sns.barplot(data=RFM_segments, x='RFM_segments', y='Customers', palette='Oranges_r')

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales). We can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
df_RFM.RFM_Level.value_counts()
# Out:
# Losted Customer                1043
# Loyal Customers                 721
# Good Customers                  581
# Try to Get Them Back            579
# Customers Needing Attention     539
# Potential Loyalist              458
# Name: RFM_Level, dtype: int64

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
df_RFM
# Out:
#             Recency  Frequency  Monetary  M  F  R  WeightedRFM_score  \
# CustomerID
# 12346.000       328          1 77183.600  4  1  1             25.000
# 12747.000         5         11  4196.010  4  4  4             40.000
# 12748.000         3        210 33053.190  4  4  4             40.000
# 12749.000         6          5  4090.880  4  3  4             37.000
# 12820.000         6          4   942.340  3  3  4             32.000
# ...             ...        ...       ... .. .. ..                ...
# 18280.000       280          1   180.600  1  1  1             10.000
# 18281.000       183          1    80.820  1  1  1             10.000
# 18282.000        10          2   178.050  1  2  4             19.000
# 18283.000         6         16  2045.530  4  4  4             40.000
# 18287.000        45          3  1837.280  4  3  3             35.000
#
#             RFM_LABEL                    RFM_Level
# CustomerID
# 12346.000   1.01.04.0  Customers Needing Attention
# 12747.000   4.04.04.0              Loyal Customers
# 12748.000   4.04.04.0              Loyal Customers
# 12749.000   4.03.04.0              Loyal Customers
# 12820.000   4.03.03.0           Potential Loyalist
# ...               ...                          ...
# 18280.000   1.01.01.0              Losted Customer
# 18281.000   1.01.01.0              Losted Customer
# 18282.000   4.02.01.0         Try to Get Them Back
# 18283.000   4.04.04.0              Loyal Customers
# 18287.000   3.03.04.0           Potential Loyalist
#
# [3921 rows x 9 columns]

# %%
df_kmeans = df_RFM[['Recency','Frequency','Monetary']]
df_kmeans
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.000       328          1 77183.600
# 12747.000         5         11  4196.010
# 12748.000         3        210 33053.190
# 12749.000         6          5  4090.880
# 12820.000         6          4   942.340
# ...             ...        ...       ...
# 18280.000       280          1   180.600
# 18281.000       183          1    80.820
# 18282.000        10          2   178.050
# 18283.000         6         16  2045.530
# 18287.000        45          3  1837.280
#
# [3921 rows x 3 columns]

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
sns.heatmap(df_kmeans.corr(), annot = True)

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
sns.pairplot(df_kmeans)

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. Logarithmic Tranformation can be used to normalize the values in a column.
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
df_kmeans_norm = df_kmeans

# %%
df_kmeans_norm['Recency'] = (df_kmeans_norm.Recency).apply(np.log)
df_kmeans_norm['Frequency'] = (df_kmeans_norm.Frequency).apply(np.log)
df_kmeans_norm['Monetary'] =( df_kmeans_norm.Monetary+1.0).apply(np.log)
df_kmeans_norm.sample(10)
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 15526.000     3.584      0.693     5.007
# 16923.000     2.708      2.944     8.864
# 13491.000     3.989      2.303     7.104
# 17455.000     5.328      0.000     4.888
# 15351.000     2.708      1.946     7.568
# 17339.000     4.575      0.693     5.499
# 16136.000     4.127      1.099     6.566
# 16814.000     2.833      3.045     8.767
# 17422.000     2.944      1.792     7.591
# 17302.000     2.833      1.609     7.036

# %%
#df_kmeans_norm[~np.isfinite(df_kmeans['Monetary'])]

# %%
sns.pairplot(df_kmeans_norm)

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
plt.rcParams['figure.facecolor'] = 'white'
model = KMeans()
visualizer = KElbowVisualizer(model, k=(4,12))

visualizer.fit(df_kmeans_norm)        # Fit the data to the visualizer
visualizer.show()

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
import matplotlib.cm as cm

# %%
for num_clusters in range(2,11):
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(df_kmeans_norm)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(df_kmeans_norm, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.4211658377439079
# For n_clusters=3, the silhouette score is 0.32517954650983
# For n_clusters=4, the silhouette score is 0.34433994223893527
# For n_clusters=5, the silhouette score is 0.32608153789873906
# For n_clusters=6, the silhouette score is 0.3156225512095251
# For n_clusters=7, the silhouette score is 0.3100833762618758
# For n_clusters=8, the silhouette score is 0.3111847174734725
# For n_clusters=9, the silhouette score is 0.2940221563281756
# For n_clusters=10, the silhouette score is 0.2893541078441882

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer

model3 = KMeans(n_clusters=6, random_state=42)
visualizer = SilhouetteVisualizer(model3)

visualizer.fit(df_kmeans_norm)    # Fit the data to the visualizer
visualizer.poof();

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
kmeans = KMeans(n_clusters = 6).fit(df_kmeans_norm)
labels = kmeans.labels_
df_kmeans_norm['labels'] = kmeans.labels_

# %%
df_kmeans_norm
# Out:
#             Recency  Frequency  Monetary  labels
# CustomerID
# 12346.000     5.793      0.000    11.254       2
# 12747.000     1.609      2.398     8.342       5
# 12748.000     1.099      5.347    10.406       5
# 12749.000     1.792      1.609     8.317       5
# 12820.000     1.792      1.386     6.849       1
# ...             ...        ...       ...     ...
# 18280.000     5.635      0.000     5.202       0
# 18281.000     5.209      0.000     4.405       0
# 18282.000     2.303      0.693     5.188       3
# 18283.000     1.792      2.773     7.624       5
# 18287.000     3.807      1.099     7.517       2
#
# [3921 rows x 4 columns]

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
plt.scatter(df_kmeans_norm.Recency, df_kmeans_norm.Frequency, c = labels, s = 50, cmap = "viridis")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s=200, c='red',alpha=0.5, label = 'Centroids');

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %%
sns.boxplot(x='labels', y='Recency', data=df_kmeans_norm)

# %%
sns.boxplot(x='labels', y='Frequency', data=df_kmeans_norm)

# %%
sns.boxplot(x='labels', y='Monetary', data=df_kmeans_norm)

# %% [markdown]
# ### iv. Assign the Label

# %%
df_kmeans_norm.reset_index(inplace = True)

# %%
df_kmeans_norm['labels'].value_counts(normalize = True)
# Out:
# 0   0.213
# 4   0.202
# 3   0.179
# 1   0.162
# 2   0.144
# 5   0.099
# Name: labels, dtype: float64

# %%
df_RFM.reset_index(inplace = True)

# %%
df_RFM['Kmeans_Label'] = df_kmeans_norm['labels']

# %%
df_RFM.sample(20)
# Out:
#       CustomerID  Recency  Frequency  Monetary  M  F  R  WeightedRFM_score  \
# 700    13804.000       33          7  2588.390  4  4  3             38.000
# 674    13761.000       53          2  1070.650  3  2  2             25.000
# 3629   17887.000      132          1   111.350  1  1  2             12.000
# 2189   15872.000       17          2   316.250  2  2  4             24.000
# 1438   14851.000       26          2   511.350  2  2  3             22.000
# 3850   18191.000      264          1   207.800  1  1  1             10.000
# 2686   16569.000        6          1   124.200  1  1  4             16.000
# 2328   16079.000       19          3  1352.000  3  3  3             30.000
# 2838   16773.000       60          1   171.590  1  1  2             12.000
# 299    13235.000      215          1  1031.070  3  1  1             20.000
# 1897   15485.000       33          3  2564.500  4  3  3             35.000
# 1493   14929.000       35          1   223.880  1  1  3             14.000
# 326    13270.000      369          1   590.000  2  1  1             15.000
# 573    13623.000       33          5   727.740  3  3  3             30.000
# 3892   18245.000       10          7  2567.060  4  4  4             40.000
# 3018   17025.000       63          3   357.770  2  3  2             23.000
# 1399   14792.000       66          1     6.200  1  1  2             12.000
# 1839   15406.000       34          2   510.710  2  2  3             22.000
# 197    13095.000       73          1    74.400  1  1  2             12.000
# 103    12962.000       10          2   266.390  1  2  4             19.000
#
#       RFM_LABEL                    RFM_Level  Kmeans_Label
# 700   3.04.04.0              Loyal Customers             2
# 674   2.02.03.0  Customers Needing Attention             4
# 3629  2.01.01.0              Losted Customer             0
# 2189  4.02.02.0  Customers Needing Attention             3
# 1438  3.02.02.0  Customers Needing Attention             3
# 3850  1.01.01.0              Losted Customer             0
# 2686  4.01.01.0         Try to Get Them Back             3
# 2328  3.03.03.0               Good Customers             1
# 2838  2.01.01.0              Losted Customer             3
# 299   1.01.03.0         Try to Get Them Back             4
# 1897  3.03.04.0           Potential Loyalist             2
# 1493  3.01.01.0              Losted Customer             3
# 326   1.01.02.0              Losted Customer             0
# 573   3.03.03.0               Good Customers             1
# 3892  4.04.04.0              Loyal Customers             5
# 3018  2.03.02.0  Customers Needing Attention             4
# 1399  2.01.01.0              Losted Customer             3
# 1839  3.02.02.0  Customers Needing Attention             3
# 197   2.01.01.0              Losted Customer             3
# 103   4.02.01.0         Try to Get Them Back             1

# %%
df_RFM.groupby(['RFM_Level','Kmeans_Label'])['RFM_LABEL'].count()
# Out:
# RFM_Level                    Kmeans_Label
# Customers Needing Attention  0                 3
#                              1               109
#                              2                 1
#                              3               117
#                              4               309
# Good Customers               1               230
#                              2                92
#                              3                 1
#                              4               258
# Losted Customer              0               751
#                              3               285
#                              4                 7
# Loyal Customers              1                98
#                              2               236
#                              5               387
# Potential Loyalist           1               186
#                              2               237
#                              4                33
#                              5                 2
# Try to Get Them Back         0                83
#                              1                14
#                              3               297
#                              4               185
# Name: RFM_LABEL, dtype: int64

# %%
df_RFM.groupby(['Kmeans_Label','RFM_Level'])['RFM_LABEL'].count()
# Out:
# Kmeans_Label  RFM_Level
# 0             Customers Needing Attention      3
#               Losted Customer                751
#               Try to Get Them Back            83
# 1             Customers Needing Attention    109
#               Good Customers                 230
#               Loyal Customers                 98
#               Potential Loyalist             186
#               Try to Get Them Back            14
# 2             Customers Needing Attention      1
#               Good Customers                  92
#               Loyal Customers                236
#               Potential Loyalist             237
# 3             Customers Needing Attention    117
#               Good Customers                   1
#               Losted Customer                285
#               Try to Get Them Back           297
# 4             Customers Needing Attention    309
#               Good Customers                 258
#               Losted Customer                  7
#               Potential Loyalist              33
#               Try to Get Them Back           185
# 5             Loyal Customers                387
#               Potential Loyalist               2
# Name: RFM_LABEL, dtype: int64

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the RFM Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# **Conclusion**
#
# * Write down your conclusions about clustering

# %% [markdown]
# Cluster 0 : The first cluster belongs to the "Best Customers" segment which we saw earlier as they purchase recently (R=4), frequent buyers (F=4), and spent the most (M=4)
#
# Cluster 1 : Second cluster can be interpreted as passer customers as their last purchase is long ago (R<=1),purchased very few (F>=2 & F < 4) and spent little (M>=4 & M < 4).Company has to come up with new strategies to make them permanent members. Low value customers
#
# Cluster 2 : The third cluster is more related to the "Almost Lost" segment as they Haven’t purchased for some time(R=1), but used to purchase frequently and spent a lot.
#
# cluster0 : Good Customer olarak adlandirilmistir.
# cluster1 : Losted Customer olarak adlandirilmistir
# cluster2 : Customers Needing Attention olarak adlandirilmistir.
# cluster3 : Potential Loyalist olarak adlandirilmistir.
# cluster4 : Try to Get Them Back olarak adlandirilmistir.
# cluster5 : Loyal Customers olarak adlandirilmistir.

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %%
df_cohort = df_uk[['InvoiceDate','CustomerID','UnitPrice','Quantity']]

# %%
df_cohort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349227 entries, 0 to 541893
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceDate  349227 non-null  datetime64[ns]
#  1   CustomerID   349227 non-null  float64
#  2   UnitPrice    349227 non-null  float64
#  3   Quantity     349227 non-null  float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 13.3 MB

# %%
df_cohort.head()
# Out:
#           InvoiceDate  CustomerID  UnitPrice  Quantity InvoiceMonth  \
# 0 2010-12-01 08:26:00   17850.000      2.550     6.000   2010-12-01
# 1 2010-12-01 08:26:00   17850.000      3.390     6.000   2010-12-01
# 2 2010-12-01 08:26:00   17850.000      2.750     8.000   2010-12-01
# 3 2010-12-01 08:26:00   17850.000      3.390     6.000   2010-12-01
# 4 2010-12-01 08:26:00   17850.000      3.390     6.000   2010-12-01
#
#   CohortMonth  Cohort_Year  Cohort_Month  Invoice_Year  Invoice_Month  index  \
# 0  2010-12-01         2010            12          2010             12      1
# 1  2010-12-01         2010            12          2010             12      1
# 2  2010-12-01         2010            12          2010             12      1
# 3  2010-12-01         2010            12          2010             12      1
# 4  2010-12-01         2010            12          2010             12      1
#
#    Total_Price
# 0       15.300
# 1       20.340
# 2       22.000
# 3       20.340
# 4       20.340

# %%
def first_of_month(date_x):    
    dt_formatted = dt.datetime.strptime(str(date_x), '%Y-%m-%d %H:%M:%S')
    return dt.datetime(dt_formatted.year, dt_formatted.month, 1)

# %%
df_cohort['InvoiceMonth'] = df_cohort['InvoiceDate'].apply(first_of_month)
df_cohort['CohortMonth'] = df_cohort.groupby('CustomerID')['InvoiceMonth'].transform('min')

# %%
df_cohort[['InvoiceDate','InvoiceMonth', 'CohortMonth']].sample(20)
# Out:
# 501207 2011-11-25 14:02:00   17883.000      1.450     1.000   2011-11-01
# 18053  2010-12-08 13:01:00   16713.000      2.950     2.000   2010-12-01
# 252350 2011-07-06 11:52:00   15021.000      1.650     2.000   2011-07-01
# 381228 2011-10-06 13:49:00   15264.000      0.830    16.000   2011-10-01
# 390722 2011-10-11 11:49:00   16837.000      2.950     6.000   2011-10-01
#
#        CohortMonth  Cohort_Year  Cohort_Month  Invoice_Year  Invoice_Month
# 409459  2011-10-01         2011            10          2011             10
# 522991  2011-09-01         2011             9          2011             12
# 306199  2011-08-01         2011             8          2011              8
# 298483  2011-08-01         2011             8          2011              8
# 221716  2010-12-01         2010            12          2011              6
# 213935  2010-12-01         2010            12          2011              6
# 494229  2010-12-01         2010            12          2011             11
# 322145  2010-12-01         2010            12          2011              9
# 208681  2011-05-01         2011             5          2011              5
# 181404  2011-01-01         2011             1          2011              5
# 423498  2011-09-01         2011             9          2011             10
# 527363  2010-12-01         2010            12          2011             12
# 334670  2010-12-01         2010            12          2011              9
# 222142  2011-06-01         2011             6          2011              6
# 340487  2011-09-01         2011             9          2011              9
# 501207  2011-04-01         2011             4          2011             11
# 18053   2010-12-01         2010            12          2010             12
# 252350  2010-12-01         2010            12          2011              7
# 381228  2011-10-01         2011            10          2011             10
# 390722  2011-04-01         2011             4          2011             10

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 separate series for each of the two columns

# %%
df_cohort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349227 entries, 0 to 541893
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceDate    349227 non-null  datetime64[ns]
#  1   CustomerID     349227 non-null  float64
#  2   UnitPrice      349227 non-null  float64
#  3   Quantity       349227 non-null  float64
#  4   InvoiceMonth   349227 non-null  datetime64[ns]
#  5   CohortMonth    349227 non-null  datetime64[ns]
#  6   Cohort_Year    349227 non-null  int64
#  7   Cohort_Month   349227 non-null  int64
#  8   Invoice_Year   349227 non-null  int64
#  9   Invoice_Month  349227 non-null  int64
# dtypes: datetime64[ns](3), float64(3), int64(4)
# memory usage: 29.3 MB

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %%
df_cohort['index'] = (df_cohort.Invoice_Year - df_cohort.Cohort_Year)*12 +( df_cohort.Invoice_Month - df_cohort.Cohort_Month)*1 + 1

# %%
df_cohort.sample(10)
# Out:
#                InvoiceDate  CustomerID  UnitPrice  Quantity InvoiceMonth  \
# 29713  2010-12-14 12:35:00   16812.000     10.950     8.000   2010-12-01
# 466140 2011-11-14 14:57:00   15058.000      4.150     6.000   2011-11-01
# 9177   2010-12-05 13:55:00   15311.000      5.950     2.000   2010-12-01
# 110209 2011-03-06 11:28:00   16923.000      1.950     2.000   2011-03-01
# 454740 2011-11-10 12:27:00   17059.000      1.450     1.000   2011-11-01
# 78247  2011-02-01 11:51:00   14606.000      0.650    12.000   2011-02-01
# 476123 2011-11-17 11:29:00   15529.000      2.950     2.000   2011-11-01
# 264685 2011-07-15 08:09:00   12928.000      1.650    10.000   2011-07-01
# 396901 2011-10-13 16:01:00   17614.000      1.250     2.000   2011-10-01
# 29216  2010-12-14 11:01:00   14524.000      0.850     6.000   2010-12-01
#
#        CohortMonth  Cohort_Year  Cohort_Month  Invoice_Year  Invoice_Month  \
# 29713   2010-12-01         2010            12          2010             12
# 466140  2011-01-01         2011             1          2011             11
# 9177    2010-12-01         2010            12          2010             12
# 110209  2010-12-01         2010            12          2011              3
# 454740  2010-12-01         2010            12          2011             11
# 78247   2010-12-01         2010            12          2011              2
# 476123  2010-12-01         2010            12          2011             11
# 264685  2010-12-01         2010            12          2011              7
# 396901  2011-10-01         2011            10          2011             10
# 29216   2010-12-01         2010            12          2010             12
#
#         index
# 29713       1
# 466140     11
# 9177        1
# 110209      4
# 454740     12
# 78247       3
# 476123     12
# 264685      8
# 396901      1
# 29216       1

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_first = df_cohort.groupby(['CohortMonth', 'index'])['CustomerID'].nunique().reset_index()
pivot_first = cohort_first.pivot(index='CohortMonth', columns='index', values='CustomerID').round(1)
pivot_first
# Out:
# index            1       2       3       4       5       6       7       8   \
# CohortMonth
# 2010-12-01  815.000 289.000 263.000 304.000 293.000 323.000 291.000 278.000
# 2011-01-01  358.000  76.000  93.000  84.000 119.000  99.000  90.000  87.000
# 2011-02-01  340.000  64.000  66.000  97.000  98.000  86.000  87.000  96.000
# 2011-03-01  419.000  64.000 109.000  83.000  94.000  69.000 111.000  96.000
# 2011-04-01  277.000  58.000  56.000  60.000  56.000  61.000  61.000  73.000
# 2011-05-01  256.000  48.000  44.000  44.000  53.000  58.000  68.000  23.000
# 2011-06-01  214.000  38.000  31.000  51.000  51.000  69.000  21.000     NaN
# 2011-07-01  169.000  30.000  33.000  39.000  47.000  18.000     NaN     NaN
# 2011-08-01  141.000  32.000  32.000  34.000  17.000     NaN     NaN     NaN
# 2011-09-01  276.000  63.000  83.000  32.000     NaN     NaN     NaN     NaN
# 2011-10-01  324.000  79.000  36.000     NaN     NaN     NaN     NaN     NaN
# 2011-11-01  298.000  35.000     NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-01   34.000     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# index            9       10      11      12      13
# CohortMonth
# 2010-12-01  289.000 325.000 299.000 405.000 218.000
# 2011-01-01  108.000 117.000 127.000  43.000     NaN
# 2011-02-01   90.000 104.000  25.000     NaN     NaN
# 2011-03-01  119.000  38.000     NaN     NaN     NaN
# 2011-04-01   20.000     NaN     NaN     NaN     NaN
# 2011-05-01      NaN     NaN     NaN     NaN     NaN
# 2011-06-01      NaN     NaN     NaN     NaN     NaN
# 2011-07-01      NaN     NaN     NaN     NaN     NaN
# 2011-08-01      NaN     NaN     NaN     NaN     NaN
# 2011-09-01      NaN     NaN     NaN     NaN     NaN
# 2011-10-01      NaN     NaN     NaN     NaN     NaN
# 2011-11-01      NaN     NaN     NaN     NaN     NaN
# 2011-12-01      NaN     NaN     NaN     NaN     NaN

# %%
sizes = pivot_first.iloc[:,0]
retention = pivot_first.divide(sizes, axis=0).round(3)*100
retention
# Out:
# index            1      2      3      4      5      6      7      8      9   \
# CohortMonth
# 2010-12-01  100.000 35.500 32.300 37.300 36.000 39.600 35.700 34.100 35.500
# 2011-01-01  100.000 21.200 26.000 23.500 33.200 27.700 25.100 24.300 30.200
# 2011-02-01  100.000 18.800 19.400 28.500 28.800 25.300 25.600 28.200 26.500
# 2011-03-01  100.000 15.300 26.000 19.800 22.400 16.500 26.500 22.900 28.400
# 2011-04-01  100.000 20.900 20.200 21.700 20.200 22.000 22.000 26.400  7.200
# 2011-05-01  100.000 18.800 17.200 17.200 20.700 22.700 26.600  9.000    NaN
# 2011-06-01  100.000 17.800 14.500 23.800 23.800 32.200  9.800    NaN    NaN
# 2011-07-01  100.000 17.800 19.500 23.100 27.800 10.700    NaN    NaN    NaN
# 2011-08-01  100.000 22.700 22.700 24.100 12.100    NaN    NaN    NaN    NaN
# 2011-09-01  100.000 22.800 30.100 11.600    NaN    NaN    NaN    NaN    NaN
# 2011-10-01  100.000 24.400 11.100    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-11-01  100.000 11.700    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-12-01  100.000    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# index           10     11     12     13
# CohortMonth
# 2010-12-01  39.900 36.700 49.700 26.700
# 2011-01-01  32.700 35.500 12.000    NaN
# 2011-02-01  30.600  7.400    NaN    NaN
# 2011-03-01   9.100    NaN    NaN    NaN
# 2011-04-01     NaN    NaN    NaN    NaN
# 2011-05-01     NaN    NaN    NaN    NaN
# 2011-06-01     NaN    NaN    NaN    NaN
# 2011-07-01     NaN    NaN    NaN    NaN
# 2011-08-01     NaN    NaN    NaN    NaN
# 2011-09-01     NaN    NaN    NaN    NaN
# 2011-10-01     NaN    NaN    NaN    NaN
# 2011-11-01     NaN    NaN    NaN    NaN
# 2011-12-01     NaN    NaN    NaN    NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(12,8))
plt.title('Retention Rate')
sns.heatmap(data=retention, annot=True, cmap='Greens', fmt='g')

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_second = df_cohort.groupby(['CohortMonth', 'index'])['Quantity'].mean().reset_index()
pivot_second = cohort_second.pivot(index='CohortMonth', columns='index', values='Quantity').round(1)
pivot_second
# Out:
# index           1      2      3      4      5      6      7       8      9   \
# CohortMonth
# 2010-12-01  11.400 12.900 13.900 13.900 13.300 13.300 14.300  13.800 16.100
# 2011-01-01  18.100  9.600  9.400 15.100 10.100 10.900 13.600  10.800 10.800
# 2011-02-01  11.000 14.000 15.900 12.100 12.300 11.900 13.900  13.700 11.000
# 2011-03-01   9.700 11.400 13.300 10.100 13.500 12.800 13.100  14.100 11.200
# 2011-04-01  10.100 10.200  9.700 11.900 11.900  8.300  9.900   9.400  7.500
# 2011-05-01  10.700  9.400 14.800 12.800 11.000  8.300 10.800 126.900    NaN
# 2011-06-01   9.500 14.800 12.000 12.700  9.800  8.900  9.400     NaN    NaN
# 2011-07-01  10.100 15.000  6.600  8.100  5.800  6.700    NaN     NaN    NaN
# 2011-08-01   9.400  6.000  5.000  5.900  6.600    NaN    NaN     NaN    NaN
# 2011-09-01  11.900  6.100  7.900  9.000    NaN    NaN    NaN     NaN    NaN
# 2011-10-01   8.700  7.200  8.200    NaN    NaN    NaN    NaN     NaN    NaN
# 2011-11-01   9.000  9.500    NaN    NaN    NaN    NaN    NaN     NaN    NaN
# 2011-12-01  15.700    NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN
#
# index           10     11     12     13
# CohortMonth
# 2010-12-01  16.100 16.700 12.400 14.500
# 2011-01-01   8.700  8.600 10.000    NaN
# 2011-02-01  12.500 13.800    NaN    NaN
# 2011-03-01   9.700    NaN    NaN    NaN
# 2011-04-01     NaN    NaN    NaN    NaN
# 2011-05-01     NaN    NaN    NaN    NaN
# 2011-06-01     NaN    NaN    NaN    NaN
# 2011-07-01     NaN    NaN    NaN    NaN
# 2011-08-01     NaN    NaN    NaN    NaN
# 2011-09-01     NaN    NaN    NaN    NaN
# 2011-10-01     NaN    NaN    NaN    NaN
# 2011-11-01     NaN    NaN    NaN    NaN
# 2011-12-01     NaN    NaN    NaN    NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(12,8))
plt.title('Average Quantity')
sns.heatmap(data=pivot_second, annot=True, cmap='Greens', fmt='g')

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %%
df_cohort['Total_Price'] = df_cohort['Quantity']* df_cohort['UnitPrice']

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_third = df_cohort.groupby(['CohortMonth', 'index'])['Total_Price'].mean().reset_index()
pivot_third = cohort_third.pivot(index='CohortMonth', columns='index', values='Total_Price').round(1)
pivot_third
# Out:
# index           1      2      3      4      5      6      7       8      9   \
# CohortMonth
# 2010-12-01  21.200 22.400 24.000 23.800 20.200 25.800 26.000  23.900 26.200
# 2011-01-01  26.700 18.800 15.400 28.200 18.600 19.100 24.200  17.800 17.800
# 2011-02-01  17.000 20.100 19.400 19.200 17.600 16.100 21.300  23.000 18.200
# 2011-03-01  16.700 20.200 22.700 17.700 20.600 18.400 20.700  19.800 16.500
# 2011-04-01  16.600 20.100 19.200 18.700 19.100 14.100 14.900  15.300 11.500
# 2011-05-01  18.100 17.000 22.000 21.100 18.700 13.500 16.700 261.800    NaN
# 2011-06-01  22.900 15.200 19.600 16.600 13.300 13.300 12.700     NaN    NaN
# 2011-07-01  14.900 24.700 10.300 12.900  9.300  9.400    NaN     NaN    NaN
# 2011-08-01  15.200 13.000 12.100 15.600 17.100    NaN    NaN     NaN    NaN
# 2011-09-01  18.300 11.500 13.700 14.000    NaN    NaN    NaN     NaN    NaN
# 2011-10-01  13.500 11.100 13.800    NaN    NaN    NaN    NaN     NaN    NaN
# 2011-11-01  11.800 13.100    NaN    NaN    NaN    NaN    NaN     NaN    NaN
# 2011-12-01  29.400    NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN
#
# index           10     11     12     13
# CohortMonth
# 2010-12-01  31.500 31.100 21.700 24.500
# 2011-01-01  17.100 18.000 19.000    NaN
# 2011-02-01  22.000 23.900    NaN    NaN
# 2011-03-01  13.100    NaN    NaN    NaN
# 2011-04-01     NaN    NaN    NaN    NaN
# 2011-05-01     NaN    NaN    NaN    NaN
# 2011-06-01     NaN    NaN    NaN    NaN
# 2011-07-01     NaN    NaN    NaN    NaN
# 2011-08-01     NaN    NaN    NaN    NaN
# 2011-09-01     NaN    NaN    NaN    NaN
# 2011-10-01     NaN    NaN    NaN    NaN
# 2011-11-01     NaN    NaN    NaN    NaN
# 2011-12-01     NaN    NaN    NaN    NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(12,8))
plt.title('Retention Rates')
sns.heatmap(data=pivot_third, annot=True, cmap='Greens')

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
